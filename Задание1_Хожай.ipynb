# %% [markdown]
# # Практическое задание №1

# %% [markdown]
# Используйте данные из файла **StudentPerformanceFactors.csv** с информацией о студентах.
#
# [Источник](https://www.kaggle.com/datasets/lainguyn123/student-performance-factors/code)
#
# В нём содержаться следующие переменные:
#
#
# | Название переменной | Описание переменной
# |:-------------------:|:------------------:|
# | Hours_Studied | Number of hours spent studying per week |
# | Attendance | Percentage of classes attended |
# | Parental_Involvement | Level of parental involvement in the student's education (Low, Medium, High)|
# | Access_to_Resources | Availability of educational resources (Low, Medium, High)|
# | Extracurricular_Activities | Participation in extracurricular activities (Yes, No).
# | Sleep_Hours | Average number of hours of sleep per night.
# | Previous_Scores |	Scores from previous exams.
# | Motivation_Level |	Student's level of motivation (Low, Medium, High).
# | Internet_Access |	Availability of internet access (Yes, No).
# | Tutoring_Sessions |	Number of tutoring sessions attended per month.
# | Family_Income |	Family income level (Low, Medium, High).
# | Teacher_Quality |	Quality of the teachers (Low, Medium, High).
# | School_Type |	Type of school attended (Public, Private).
# | Peer_Influence |	Influence of peers on academic performance (Positive, Neutral, Negative).
# | Physical_Activity |	Average number of hours of physical activity per week.
# | Learning_Disabilities |	Presence of learning disabilities (Yes, No).
# | Parental_Education_Level |	Highest education level of parents (High School, College, Postgraduate).
# | Distance_from_Home |	Distance from home to school (Near, Moderate, Far).
# | Gender |	Gender of the student (Male, Female).
# | Exam_Score |	Final exam score.

# %% [markdown]
# Выполните, пожалуйста, следующие задания.

# %% [markdown]
# 1. Опишите датасет (число наблюдений и переменных, пропущенных значений, типы данных, типы шкал переменных).

# %%
# здесь можно написать код
import numpy as np
import pandas as pd

# %%
url = '/content/StudentPerformanceFactors.csv'

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.info()
#информация о датафрейме: кол-во ненулевых значений по всем переменным, кол-во переменных, типе данных переменных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.isnull().sum()
#количество пропущенных значений по переменным
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %% [markdown]
# Общее количество наблюдений - 6607. Количество переменных - 20. Есть пропущенные значения по переменным Teacher_Quality (78 пропущенных значений), Parental_Education_Level (90 значений), Distance_from_Home (67 значений).
#
# **Тип данных в датасете** - перекрестные. Представлены данные типа integer и object. 7 переменных типа integer - Hours_Studied, Attendance, Sleep_Hours, Previous_Scores, Tutoring_Sessions, Physical_Activity, Exam_Score. 13 переменных типа object - Extracurricular_Activities, Internet_Access, School_Type, Learning_Disabilities, Gender, Parental_Education_Level, Parental_Involvement, Access_to_Resources, Motivation_Level, Family_Income, Teacher_Quality, Distance_from_Home, Peer_Influence.
#
# **Типы шкал переменных**:
#
# Номинальные переменные: Extracurricular_Activities, Internet_Access, School_Type, Learning_Disabilities, Gender.
#
# Порядковые переменные: Parental_Education_Level, Parental_Involvement, Access_to_Resources, Motivation_Level, Family_Income, Teacher_Quality, Distance_from_Home, Peer_Influence.
#
# Абсолютные переменные: Exam_Score, Previous_Scores, Attendance.
#
# Интервальные переменные: Hours_Studied, Tutoring_Sessions, Sleep_Hours, Physical_Activity.

# %% [markdown]
# 2. Проведите описательный анализ переменных датасета, используя подходящие методы анализа в зависимости от типа шкалы измерения переменной (частотный анализ данных, сводные таблицы, меры центральной тенденции и меры разброса, характеристики распределений переменных, графический анализ данных). Интерпретируйте полученные результаты. Обратите внимание, что анализ данных предполагает следующие этапы:
# - постановка задачи и выбор переменных,
# - обоснование выбора метода анализа,
# - проведение расчётов,
# - интерпретация результатов.
#
# Например, я хотела бы проанализировать физическую активность студентов. Для этого я рассматриваю переменную "Physical_Activity". Поскольку она имеет метрическую шкалу измерения для ее анализа целесообразно построить гистограмму распределения значений и рассчитать описательные статистики. Далее делаете выводы на основе проведенных расчётов.

# %% [markdown]
# Описание переменных:
#
# Постановка задачи: проанализировать количество часов, затраченных на учебу студентами. Для этого рассматривается переменная "Hours_Studied" . Поскольку она имеет абсолютную шкалу измерения, для ее анализа целесообразно

# %%
df.describe()
#для количественных переменных
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %% [markdown]
# Вывод: На основе анализа описательной статистики можно сделать вывод, что в среднем студенты учились почти 20 часов в неделю. Причем максимальное количество часов, посвященных учебе, могло достигать 44 часа, а минимальное - 1 час в неделю. В соответствии со значением 3 квартиля, 75% всех студентов посвящали учебе до 24 часов в неделю. Наблюдается большой размах значений в данных.
# В среднем студенты посетили 80% занятий. Минимально 60%. То есть все студенты как минимум посетили большую часть занятий. Из особенностей можно отметить высокое значение стандартного отклонения (11,5), что говорит о сильном отклонении значений от среднего. Высокое значение стандартного отклонения также наблюдается по переменной Previous_Scores, где тоже можно говорить о большом отклонении от среднего. В случае с переменной Exam_Score отклонение текущих результатов экзамена от среднего в разы ниже (все результаты студентов в целом близки к среднему). Сравнивая результаты текущего и прошлого экзамена, можно сказать, что в среднем студенты стали писать экзамен хуже (67,2 vs 75). У 75% студентов результат по прошлому экзамену распределяют до 88 баллов, а по текущему - до 69 баллов. В среднем студенты хорошо спят, по 7 часов. А больше и не рекомендовано, вредно для здоровья.

# %%
df.mode()
#значения, наиболее часто встречающиеся в выборке, по всем переменным (включая переменные типа object)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             20          67               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                        Yes            7               66           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  1           Low          Medium
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
#
#   Parental_Education_Level Distance_from_Home Gender  Exam_Score
# 0              High School               Near   Male          68

# %% [markdown]
# Распределения переменных типа object больше характеризует значение моды. По результатам расчета моды можно сделать вывод, что в большей части случаев прослеживается средний уровень вовлеченности родителей в обучение, средний уровень доступа к образованию и среднюю мотивацию в изучению предмета. У большей части студентов есть доступ к Интернету, нет ограничений по здоровью. Большая часть студентов мужского пола, с родителями, имеющими высшее образование, из семей с низким уровнем дохода. Большая часть студентов посещает государственные образовательные учреждения, проживают близко к месту обучения.
# Качество преподавания в большинстве случаев среднего уровня. Влияение сверстников на учебу положительное.

# %% [markdown]
# **Задача**: проанализируем количество часов, потраченное на учебу студентами (Hours_Studied).

# %%
#зависимость Hours_Studied от Parental_Involvement
df.pivot_table(index=['Parental_Involvement'], values=['Hours_Studied'], aggfunc=['mean', 'max']).round(2)
# Out:
#                               mean           max
#                      Hours_Studied Hours_Studied
# Parental_Involvement
# High                         19.85            44
# Low                          20.13            38
# Medium                       19.98            39

# %%
df.plot.scatter(x = 'Hours_Studied', y = 'Exam_Score')
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Exam_Score'>

# %% [markdown]
# В своей основной массе видна прямая зависимость между количеством часов, потраченных на обучение и результатом экзамена (чем больше часов занимался студент, тем выше оценку он получил). Тем не менее, наравне с общей тенденцией наблюдается ряд выбросов, которые составляют скорее исключения из правила.

# %%
df['Hours_Studied'].corr(df['Exam_Score'])
# Out:
# 0.44545495407528235

# %% [markdown]
# Наблюдается положительная корреляция между результатами экзамена и временем, которое студенты уделили учебе. При этом более значимая корреляция прослеживается для студентов, получивших за экзамен меньше 80. Менее явная взаимосвязь в случае со студентами с баллами выше 80.

# %%
df.pivot_table(index=['Access_to_Resources'], values=['Hours_Studied'], aggfunc=['mean']).round(2)
# Out:
#                              mean
#                     Hours_Studied
# Access_to_Resources
# High                        20.00
# Low                         20.12
# Medium                      19.91

# %% [markdown]
# Из таблицы можно сделать вывод о количестве часов, потраченных на учебу в зависимости от доступа к ресурсам. Учитывая, что между уровням "низкий" и "высокий" разницы в часах практически нет, можно сделать вывод, что доступ к ресурсам не влияет на количество учебных часов.

# %%
df.pivot_table(index=['Gender'], values=['Hours_Studied'], aggfunc=['mean', 'max']).round(2)
# Out:
#                 mean           max
#        Hours_Studied Hours_Studied
# Gender
# Female         20.01            44
# Male           19.95            39

# %% [markdown]
# Сводная таблциа дает представление о среднем и максимальном количестве часов, проведенных за учебой. Заметим, что срение значения составляют половину от максимальных.

# %%
df.pivot_table(index=['Motivation_Level'], values=['Hours_Studied'], aggfunc=['mean']).round(2)
# Out:
#                           mean
#                  Hours_Studied
# Motivation_Level
# High                     19.73
# Low                      19.96
# Medium                   20.08

# %% [markdown]
# Сводная таблица отражает количество часов, затраченных на учебу в зависимости от уровня мотивации студента. В данных нет явной зависимости от уровня мотивации применительно к часам, проведенным за учебой: при средней мотивации студент тратил больше времени за учебой, чем при высокой,что является контринтуитивным результатом. Если бы речь шла именно про результаты, можно было бы сказать, что данная талица наглядно отражает действие эмпирического закона Йерска-Додсона, который гласит, что максимальных результатов достигает человек со средним уровнем мотивации. Однако, так как речь идет именно про процесс (учебу), а не результат (оценка на экзамене), то результат является крайне странным.

# %%
df.pivot_table(index=['Gender'], columns = ['Peer_Influence'], values=['Hours_Studied'], aggfunc=['mean']).round(2)
# Out:
#                         mean
#                Hours_Studied
# Peer_Influence      Negative Neutral Positive
# Gender
# Female                 20.00   19.82    20.18
# Male                   19.87   19.97    19.98

# %% [markdown]
# Можно отметить, что у парней прослеживается более явная взаимосвязь между количеством часов, посвященным учебе и влиянием сверстников. С ростом "позитивности" влияния, растет и их время, затраченное на учебу. У девушек взаимосвязи не прослеживается. Хотя в среднем время, потраченное на учебу, при позитивном влиянии сверстников наибольшее, то при негативном влиянии оно мало чем отличается. Самое низкое - при нейтральном влиянии.

# %% [markdown]
# P.S. Из корреляционный таблицы, построенной в пункте 3.8 можно отметить, что переменная Hours_Studied не имеет значимой корреляции с другими перемеными (кроме Exam_Score).

# %% [markdown]
# **Задача**: проанализируем посещаемость занятий (Attendance) и уровень мотивации к обучению (Motivation_Level).

# %%
df.plot.scatter(x = 'Attendance', y = 'Exam_Score')
# Out:
# <Axes: xlabel='Attendance', ylabel='Exam_Score'>

# %% [markdown]
# В среднем видна тенденция к более высокой оценке за экзамен при более высокой посещаемости (прямая зависимость двух переменных). Выбросы имеют место, но составляют меньшинство и могут считаться исключением из правила.

# %%
df.pivot_table(index=['Gender'], columns = ['Motivation_Level'], values=['Attendance'], aggfunc=['mean']).round(2)
# Out:
#                        mean
#                  Attendance
# Motivation_Level       High    Low Medium
# Gender
# Female                79.74  79.97  79.86
# Male                  79.70  79.91  80.28

# %% [markdown]
# Сводная таблица дает представление о среднем уровне посещаемости среди мужского и женского пола с разделением по уровню мотивации. Из табллицы следует, что для обоих полов посещаемость при заданном уровне мотивации практически идентична.

# %%
df.pivot_table(index=['Gender'], columns = ['Motivation_Level'], values=['Sleep_Hours'], aggfunc=['mean']).round(2)
# Out:
#                         mean
#                  Sleep_Hours
# Motivation_Level        High   Low Medium
# Gender
# Female                  7.00  7.11   7.02
# Male                    7.05  6.96   7.04

# %% [markdown]
# Сводная таблица дает представление о среднем количестве часов сна среди мужского и женского пола с разделением по уровню мотивации. Из таблицы следует, что паттерны сна среди обоих полов внутри заданного уровня мотивации практически идентичны. Интересно, что большая мотивация не означает меньшее количество часов сна, что было ожидаемым выводом, поскольку, если человек хорошо мотивирован учиться, то должен легко жертвовать такими мелочами как здоровая нервная система и сон.

# %%
df.pivot_table(index=['Gender'], columns = ['Peer_Influence'], values=['Attendance'], aggfunc=['mean']).round(2)
# Out:
#                      mean
#                Attendance
# Peer_Influence   Negative Neutral Positive
# Gender
# Female              79.91   80.33    79.41
# Male                79.63   80.42    79.91

# %% [markdown]
# Сводная таблица дает представление о срелних данных по посещаемости с разделением по уровню влияния сверстников. Из таблица следует, что влияние сверстников не оказывает большого влияния на посещаемость, поскольку, в среднем, значения практически не меняются и находятся в интервале от 79 до 80.

# %%
df.groupby('Gender')['Motivation_Level'].value_counts().to_frame()
# Out:
#                          count
# Gender Motivation_Level
# Female Medium             1404
#        Low                 841
#        High                548
# Male   Medium             1947
#        Low                1096
#        High                771

# %% [markdown]
# Сводная таблица дает представление об уровне мотивации студентов в разбирвкой по полу, а также (внутри категорий) по уровню мотивации уже внутри него. В каждой подкатегории с уровнем мотивации мужчины имеют значительный отрыв от женщин. В разных категориях отрыв составляет четверть или даже треть по отношению к базовому значению.

# %%
df.pivot_table(index=['Gender'], columns = ['Parental_Involvement'], values=['Attendance'], aggfunc=['mean']).round(2)
# Out:
#                            mean
#                      Attendance
# Parental_Involvement       High    Low Medium
# Gender
# Female                    80.00  80.02  79.73
# Male                      79.91  80.51  79.96

# %% [markdown]
# Сводная таблица дает представление о среднем уровне посещаемости в зависимости от включенности (участия) родителей в  обучение своих детей. Средние значения внутри одного уровня посещаемости незначительного отличаются в зависимости от пола.

# %% [markdown]
# **Гистограммы**

# %%
import matplotlib.pyplot as plt
df.Sleep_Hours.hist(bins=20)
plt.xlabel('Количество часов сна')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# Гистограмма дает общее представление о привычках студентов применительно ко сну. Основываясь на визуальных данных (самому высокому стобцу) можно определить моду, то есть самое частовстречающееся количество часов, которое спят студенты. В данном случае этот показатель равен 7 (часам). В целом, можно расширить данный вывод и сказать, что подавляющее большинство студентов спит по 7-8 часов ежедневно. Также имеют место выбросы (нетипичные паттерны поведения), которые выражаются в крайнем малом или наоборот большом количестве часов сна (в данном случае - 4 и 10 часов).

# %%
df.Tutoring_Sessions.hist(bins=20)
plt.xlabel('Количество дополнительных занятий')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# Гистограма дает общее представление о  возможностях дополнительного образования (в данном конкретном случае - количество дополнительных занятий). Самое частовстречающееся значение (мода) - 1, то есть чаще  всего на одного студента приходится одно дополнительное занятие. Гистограмма скршена вправо, отсюда можно сделать вывод, что большинство студентов ходит на 2 и более дополнительных занятия (именно суммарно по категориям 2,3,4,5,6,7 занятий).

# %% [markdown]
# **Круговые диаграммы**

# %% [markdown]
# Проверим процентное соотношение категорий для всех порядковых и номинальных переменных.

# %%
df.groupby('Parental_Involvement').size().plot(kind='pie', title = 'Вовлеченность родителей в обучение', autopct='%.2f')
# Out:
# <Axes: title={'center': 'Вовлеченность родителей в обучение'}>

# %% [markdown]
# Диаграмма дает представление о вовлеченности родителей в процесс обучения своих детей. Подавляющее большинство родителй вовлечены в обучение на среднем уровне. Чуть меньше трети родителей вовлечены в обчение больше остальных. Меньше всех в абсолютном выражении родителей, которые минимально вовлечены в обучение.

# %%
df.groupby('Access_to_Resources').size().plot(kind='pie', title = 'Доступ к образованию', autopct='%.2f')
# Out:
# <Axes: title={'center': 'Доступ к образованию'}>

# %% [markdown]
# Диаграмма дает представление о доступе к образованию. Уровень для подавляющего большинствао оценивается как "средний", уровень подавляющего меньшинства оценивается как "низкий", уровень оставшихся респондентов, составляющих немногим меньше трети оценивается как "высокий".

# %%
df.groupby('Motivation_Level').size().plot(kind='pie', title = 'Уровень мотивации', autopct='%.2f')
# Out:
# <Axes: title={'center': 'Уровень мотивации'}>

# %% [markdown]
# Диаграмма дает представление об уровне мотивации респондентов. Уровень для подавляющего большинствао оценивается как "средний", уровень подавляющего меньшинства оценивается как "высокий", уровень оставшихся респондентов, составляющих немногим меньше трети оценивается как "низкий".

# %%
df.groupby('Family_Income').size().plot(kind='pie', title = 'Уровень дохода семьи', autopct='%.2f')
# Out:
# <Axes: title={'center': 'Уровень дохода семьи'}>

# %% [markdown]
# Диаграмма дает представление об уровне дохода  семей респондентов. Уровень для подавляющего большинствао оценивается как "низкий", уровень подавляющего меньшинства оценивается как "высокий", уровень оставшихся респондентов, составляющих немногим меньше половины оценивается как "низкий".

# %%
df.groupby('Parental_Education_Level').size().plot(kind='pie', title = 'Уровень образования родителей', autopct='%.2f')
# Out:
# <Axes: title={'center': 'Уровень образования родителей'}>

# %% [markdown]
# Диаграмма дает представление об уровне образования родителей респондентов. Уровень образования подавляющего большинства родителей респондентов находится на уровне старшей школы, уровень подавляющего меньшинства родителей респондентов находится на уровне аспирантуры, уровень оставшихся респондентов, составляющих немногим больше трети находится на уровне университета.

# %%
df.groupby('School_Type').size().plot(kind='pie', title = 'Вид образовательного учреждения', autopct='%.2f')
# Out:
# <Axes: title={'center': 'Вид образовательного учреждения'}>

# %% [markdown]
# По данным круговой диаграммы, что 30,41% студентов посещает частную школу, 69,59% - государственные.

# %%
df.groupby('Peer_Influence').size().plot(kind='pie', title = 'Вид образовательного учреждения', autopct='%.2f')
# Out:
# <Axes: title={'center': 'Вид образовательного учреждения'}>

# %% [markdown]
# В целом влияние сверстников примерно в равной доле либо позитивное, либо нейтральное (39,2% - 39,9%). В 20,8% случаев влияние сверстников на обучение негативно.

# %%
df.groupby('Distance_from_Home').size().plot(kind='pie', title = 'Удаленность от места обучения', autopct='%.2f')
# Out:
# <Axes: title={'center': 'Удаленность от места обучения'}>

# %% [markdown]
# Диаграмма дает представление об удаленности места учебы от дома. Подавляющее кличество респондентов живут недалеко от места учебы, около трети респондентов живут в приемлемой географической близости от места учебы, подавляющее меньшнство живет далеко от учебы.

# %%
df.groupby('Gender').size().plot(kind='pie', title = 'Пол', autopct='%.2f')
# Out:
# <Axes: title={'center': 'Пол'}>

# %% [markdown]
# Среди студентов 57,7% парни, 42,27% - девушки.

# %%
df.groupby('Internet_Access').size().plot(kind='pie', title = 'Доступ к Интернету', autopct='%.2f')
# Out:
# <Axes: title={'center': 'Доступ к Интернету'}>

# %% [markdown]
# Диаграмма дает представление о доступе к Интернету у респондентов. У подавляющего большинства респондентов есть доступ в Интернет, у подавляющего меньшинства респондентов нет доступа в Интернет.

# %% [markdown]
# **Столбчатые диаграммы**

# %% [markdown]
# 3. Ответьте на вопросы (возможно, на некоторые из них Вы уже ответили в предыдущем пункте):
#     - Какой процент студентов имеют высокую мотивированию?
#     - Какого соотношение числа студентов с разным уровнем вовлеченности родителей в их обучение по группам уровня дохода семьи?
#     - Наблюдается ли взаимосвязь между числом часов сна ночью и посещаемостью занятий?
#     - Как различаются оценки юношей и девушек, живущих в разной удаленности от места обучения?
#     - Какова специфика распределения финальных оценок за экзамен?
#     - Наблюдается ли взаимосвязь между уровнем мотивации студентов и качеством преподавания?
#     - Какими характеристиками обладают студенты-отличники (сами определите каких студентов отнести к отличникам)?
#     - Какие факторы положительно взаимосвязаны с результатами экзамена (на этом этапе мы изучаем взаимосвязи на основе описательного анализа данных)?
#     - Какие переменные имеют распределение, близкое к нормальному?
#     - В распределении значений каких метрических переменных наблюдается асимметрия?

# %% [markdown]
# 3.1. Процент студентов с высокой мотивированностью. Переменная Motivation_Level.

# %%
df['Motivation_Level'].value_counts(normalize=True).to_frame().round(2)
#расчет процентов через частотные таблицы
# Out:
#                   proportion
# Motivation_Level
# Medium                  0.51
# Low                     0.29
# High                    0.20

# %% [markdown]
# Процент студентов с высокой мотивированностью составляет 20%.

# %% [markdown]
# 3.2. Соотношение числа студентов с разным уровнем вовлеченности родителей в их обучение по группам уровня дохода семьи (в %).

# %%
df.groupby('Family_Income')['Parental_Involvement'].value_counts(normalize=True).to_frame()
#процентное соотношение числа студентов по уровню вовлеченности родителей в учебу в зависимости от уровня дохода семьи
# Out:
#                                     proportion
# Family_Income Parental_Involvement
# High          Medium                  0.511426
#               High                    0.290780
#               Low                     0.197794
# Low           Medium                  0.498877
#               High                    0.287425
#               Low                     0.213698
# Medium        Medium                  0.517629
#               High                    0.289197
#               Low                     0.193173

# %% [markdown]
# Вывод: На основе таблицы можно заметить, что при любом уровне дохода семьи соотношение степени участия родителей в образовании особенно не меняется. При любом уровне дохода доминирует средняя степень участия родителей (до 50-51%). Сильное участие на втором месте по процентному соотношению (приблизительно 29%). Доля низкой вовлеченности в образование наиболее высокая в семьях с низким благосостоянием.

# %% [markdown]
# 3.3. Проверка наличия взаимосвязи между числом часов сна ночью (Sleep_Hours) и посещаемостью занятий (Attendance)

# %%
df.groupby('Sleep_Hours')['Attendance'].mean()
# Out:
# Sleep_Hours
# 4     81.242718
# 5     80.397122
# 6     79.526163
# 7     80.142447
# 8     79.849178
# 9     79.925161
# 10    79.564103
# Name: Attendance, dtype: float64

# %%
df.pivot_table(index=['Sleep_Hours'], values=['Attendance'], aggfunc=['mean', 'median'])
# Out:
#                   mean     median
#             Attendance Attendance
# Sleep_Hours
# 4            81.242718       82.0
# 5            80.397122       80.0
# 6            79.526163       80.0
# 7            80.142447       80.0
# 8            79.849178       79.0
# 9            79.925161       80.0
# 10           79.564103       79.5

# %%
df['Sleep_Hours'].corr(df['Attendance']).round(3)
# Out:
# -0.016

# %% [markdown]
# Вывод: по данным сводных таблиц нельзя проследить явной взаимосвязи между количеством часов сна и посещаемостью занятий нельзя. Взаимосвязи между этими переменными нет. Результат расчета показателя корреляции также продемонстрировал отсутствие значимой взаимосвязи, так как значение по модулю близко к 0.

# %% [markdown]
# 3.4. Как различаются оценки юношей и девушек, живущих в разной удаленности от места обучения?

# %%
#переменные Exam_Score, Gender и Distance_from_Home
df.pivot_table(index=['Gender'], columns = ['Distance_from_Home'], values=['Exam_Score']).round(2)
#автоматически рассчитываются средние оценки по переменной Exam_Score (текущие оценки за экзамен)
# Out:
#                    Exam_Score
# Distance_from_Home        Far Moderate   Near
# Gender
# Female                  66.15    66.92  67.62
# Male                    66.68    67.03  67.44

# %%
df.pivot_table('Exam_Score', index=['Gender'], columns = ['Distance_from_Home'], aggfunc='max')
#расчет максимальной оценки в зависимости от пола студентов и удаленности от места обучения
# Out:
# Distance_from_Home  Far  Moderate  Near
# Gender
# Female               94       101   100
# Male                 99        94    98

# %%
df.pivot_table('Exam_Score', index=['Gender'], columns = ['Distance_from_Home'], aggfunc='min')
#расчет минимальной оценки в зависимости от пола студентов и удаленности от места обучения
# Out:
# Distance_from_Home  Far  Moderate  Near
# Gender
# Female               57        58    57
# Male                 56        57    55

# %%
#переменные Previous_Scores, Gender и Distance_from_Home
df.pivot_table(index=['Gender'], columns = ['Distance_from_Home'], values=['Previous_Scores']).round(2)
#автоматически рассчитываются средние оценки по переменной Previous_Scores (оценки за предыдущий экзамен)
# Out:
#                    Previous_Scores
# Distance_from_Home             Far Moderate   Near
# Gender
# Female                       75.57    74.91  75.03
# Male                         74.74    74.84  75.29

# %%
df.pivot_table('Previous_Scores', index=['Gender'], columns = ['Distance_from_Home'], aggfunc='max')
#расчет максимальной оценки в зависимости от пола студентов и удаленности от места обучения
# Out:
# Distance_from_Home  Far  Moderate  Near
# Gender
# Female              100       100   100
# Male                100       100   100

# %%
df.pivot_table('Previous_Scores', index=['Gender'], columns = ['Distance_from_Home'], aggfunc='min')
#расчет минимальной оценки в зависимости от пола студентов и удаленности от места обучения
# Out:
# Distance_from_Home  Far  Moderate  Near
# Gender
# Female               50        50    50
# Male                 50        50    50

# %% [markdown]
# Вывод: Как в случае текущих, так и в случае прошлых результатов нет большой разницы между средними результатами юношей и девушек. Можно сказать, что по результатам текущего экзамена, со снижением удаленности от дома, и у парней, и у девушек возрастают баллы по экзамену. Если рассматривать максимум по Exam_Score, максимальный балл чаще у студентов-парней, живущих далеко от места обучения, но чаще у девушек, проживающих в средней или большой удаленности от места обучения.
#
# По переменной Previous_Scores: в среднем результаты выше у девушек при большой удаленности и средней удаленности, но выше у парней при низкой удаленности от дома. У парней прослеживается взаимосвязь с изменением удаленности от дома: чем ближе учатся, чем выше результаты экзамена. У девушек нет. самый высокий результат - при наибольшей удаленности от места учебы.
#
# Уровень минимальной оценки стал выше по результатам текущего экзамена, то есть студенты с наиболее низкими оценками стали писать экзамен лучше. Но если разницы в зависимости от половой принадлежности и удаленности от места обучения раньше не наблюдалось, в Exam_Score минимальная оценка девушек стала выше (с удаленностью нет явной взаимосвязи).

# %% [markdown]
# 3.5. Какова специфика распределения финальных оценок за экзамен?

# %% [markdown]
# Для определения специфики распределения построим гистограмму.

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from scipy.stats import norm

# %%
sns.distplot(df.Exam_Score.dropna(), fit=norm) #гистограмма и сравнение распределения с нормальным
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Density'>

# %% [markdown]
# Распределение переменной приближено к нормальному распределению. Тем не менее, есть ассиметрия.

# %% [markdown]
# 3.6. Наблюдается ли взаимосвязь между уровнем мотивации студентов и качеством преподавания?

# %%
#переменные Motivation_Level и Teacher_Quality
df.groupby('Motivation_Level')['Teacher_Quality'].value_counts().to_frame()
# Out:
#                                   count
# Motivation_Level Teacher_Quality
# High             Medium             767
#                  High               405
#                  Low                134
# Low              Medium            1173
#                  High               582
#                  Low                156
# Medium           Medium            1985
#                  High               960
#                  Low                367

# %% [markdown]
# Вывод: взаимосвязи не наблюдается. Если рассматривать самый высокий уровень мотивации, то видно, что наиболее часто в выборке встречаются случаи, когда уровень преподавания при этом средний. Наиболее частый случай, когда и уровень образования, и уровень мотивации средний. Много ситуаций, когда уровень мотивации низкий даже при среднем уровне преподавания. Таким образом, связи не наблюдается.

# %% [markdown]
# 3.7. Какими характеристиками обладают студенты-отличники (сами определите каких студентов отнести к отличникам)?

# %% [markdown]
# Будем считать студента отличником, если его оценка за оба экзамена превышает 80 (Exam_Score >= 80 и Previous_Scores >= 80).

# %%
df_filt = df[(df['Exam_Score'] >= 80) & (df['Previous_Scores'] >= 80)]
df_filt
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 529              15          83               Medium              Medium
# 770              24          96                  Low                High
# 836              29          76               Medium              Medium
# 919              21          74                 High              Medium
# 1525             27          98                  Low              Medium
# 1607             30          98               Medium                 Low
# 2425             23          83                 High                High
# 2954             14          75               Medium              Medium
# 3124             19          90               Medium                High
# 3141              7          63                 High                High
# 3579             14          90                 High                High
# 4192             28          90                  Low              Medium
# ...

# %%
df_filt.describe().round(2)
# Out:
#        Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# count          18.00       18.00        18.00            18.00
# mean           21.39       82.78         6.72            92.28
# std             6.41       12.58         1.71             3.21
# min             7.00       61.00         4.00            86.00
# 25%            16.50       74.25         6.00            90.00
# 50%            22.00       83.00         6.50            92.50
# 75%            26.75       94.50         8.00            94.75
# max            30.00       98.00        10.00            98.00
#
#        Tutoring_Sessions  Physical_Activity  Exam_Score
# count              18.00              18.00       18.00
# mean                1.44               2.72       93.72
# std                 1.42               0.96        5.97
# min                 0.00               1.00       80.00
# 25%                 0.25               2.00       93.25
# 50%                 1.00               3.00       94.50
# ...

# %%
df_filt.describe(include='object') #мода для категориальных переменных
# Out:
#        Parental_Involvement Access_to_Resources Extracurricular_Activities  \
# count                    18                  18                         18
# unique                    3                   3                          2
# top                  Medium              Medium                        Yes
# freq                      8                   9                         13
#
#        Motivation_Level Internet_Access Family_Income Teacher_Quality  \
# count                18              18            18              18
# unique                3               2             3               3
# top              Medium             Yes           Low          Medium
# freq                  9              16             8              10
#
#        School_Type Peer_Influence Learning_Disabilities  \
# count           18             18                    18
# unique           2              3                     2
# top         Public       Positive                    No
# ...

# %% [markdown]
# Вывод: студентов-отличников (с баллом больше 80) 18 человек. В среднем эти студенты учились 21,39 часов в неделю, максимально 30. Посетили в среднем 82,8% занятий. В среднем студенты-отличники спали 6,7 часов. Если брать в учет категориальные переменные, отличники преимущественно происходят из семей с низким уровнем дохода, посещают дополнительные занятия, обучаются в государственных школах, являются девушками, живут в низкой удаленности от места обучения. Это студенты со средней мотивированностью, средним уровнем вовлеченности родителей в обучение. Уровень преподавания предмета у этих студентов тоже средний. Наблюдается в большинстве случаев позитивное влияние сверстников. Родители этих студентов в большинстве случаев имеют высшее образование.

# %% [markdown]
# 3.8. Какие факторы положительно взаимосвязаны с результатами экзамена (на этом этапе мы изучаем взаимосвязи на основе описательного анализа данных)?

# %% [markdown]
# Для определения наличия и характера взаимосвязи проведем корреляционный анализ количественных переменных. Чтобы рассмотреть корреляцию с качественными переменными, перекодируем данные.

# %%
df_dcd = pd.read_csv('/content/StudentPerformanceFactors.csv')
df_dcd.replace({
    'Parental_Education_Level': {'High School': 0, 'College': 1, 'Postgraduate': 2},
    'Gender': {'Female': 0, 'Male': 1},
    'Motivation_Level': {'Low': 0, 'Medium': 1, 'High': 2},
    'Parental_Involvement': {'Low': 0, 'Medium': 1, 'High': 2},
    'Learning_Disabilities': {'No': 0, 'Yes': 1},
    'Access_to_Resources': {'Low': 0, 'Medium': 1, 'High': 2},
    'Family_Income': {'Low': 0, 'Medium': 1, 'High': 2},
    'Access_to_Resources': {'Low': 0, 'Medium': 1, 'High': 2},
    'Extracurricular_Activities': {'No': 0, 'Yes': 1},
    'Teacher_Quality': {'Low': 0, 'Medium': 1, 'High': 2},
    'Internet_Access': {'No': 0, 'Yes': 1},
    'School_Type':{'Private': 0, 'Public': 1},
    'Distance_from_Home': {'Near': 0, 'Moderate': 1, 'Far': 2},
    'Peer_Influence':{'Negative': 0, 'Neutral': 1, 'Positive': 2}

}, inplace=True)
df_dcd
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df_dcd.corr(numeric_only=True).round(3)
# Out:
#                             Hours_Studied  Attendance  Parental_Involvement  \
# Hours_Studied                       1.000      -0.010                -0.016
# Attendance                         -0.010       1.000                -0.009
# Parental_Involvement               -0.016      -0.009                 1.000
# Access_to_Resources                -0.005      -0.012                -0.027
# Extracurricular_Activities         -0.006      -0.002                -0.022
# Sleep_Hours                         0.011      -0.016                -0.008
# Previous_Scores                     0.025      -0.020                -0.021
# Motivation_Level                   -0.010      -0.005                -0.022
# Internet_Access                     0.005      -0.018                 0.012
# Tutoring_Sessions                  -0.014       0.014                -0.002
# Family_Income                       0.001      -0.013                 0.012
# ...

# %% [markdown]
# Вывод. Наиболее явная корреляция прослеживается у переменных с Exam_Score: Hours_Studied(0,445), Attendance(0,581), Parental_Education_Level(0,194), Parental_Involvement(0,157), Access_to_Resources(0,17), Previous_Scores(0,175), Tutoring_Sessions(0,157). Значения корреляции с этими переменными у Exam_Score наиболее высокие. Положительная, но низкая корреляция с переменными Family_Income(0,095), Teacher_Quality(0,076), Motivation_Level(0,087), School_Type(0,009), Peer_Influence(0,1) Physical_Activity(0,028), Learning_Disabilities(0,085). В целом корреляция является довольно слабой.

# %% [markdown]
# 3.9. Какие переменные имеют распределение, близкое к нормальному?

# %% [markdown]
# Проверим распределение количественных переменных (типа integer) и сравним их с нормальным. Переменные Hours_Studied, Attendance, Sleep_Hours, Previous_Scores, Tutoring_Sessions, Physical_Activity, Exam_Score.
#
# Вывод: переменные Exam_Score, Hours_Studied имеют распределение, близкое к нормальному.

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from scipy.stats import norm
sns.distplot(df.Exam_Score.dropna(), fit=norm)
#распределение Exam_Score приближено к нормальному
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Density'>

# %% [markdown]
# График дает наглядное представление о распределении экзаменационных баллов студентов. Распределение переменной приближено к нормальному распределению. Тем не менее, есть ассиметрия. Большинство студентов получают баллы в диапазоне от 60 до 70 баллов.

# %%
sns.distplot(df.Previous_Scores.dropna(), fit=norm)
#распределение не является близким к нормальному
# Out:
# <Axes: xlabel='Previous_Scores', ylabel='Density'>

# %% [markdown]
# График дает представление о распределении баллов предыдущих студентов. Распределение переменной не приближено к нормальному распределению (не является близким к нему). Имеет место большой разброс данных, баллы студентов сильно различаются.

# %%
sns.distplot(df.Attendance.dropna(), fit=norm)
#распределение переменной не является близким к нормальному
# Out:
# <Axes: xlabel='Attendance', ylabel='Density'>

# %% [markdown]
# График дает представление о рапрседелении данных по посещаемости студентов. Распределение переменной не приближено к нормальному распределению (не является близким к нему). Имеет место большой разброс данных, посещаемость студентов сильно различается.

# %%
sns.distplot(df.Hours_Studied.dropna(), fit=norm)
#распределение приближено к нормальному
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Density'>

# %% [markdown]
# Распределение переменной приближено к нормальному распределению. Тем не менее, есть ассиметрия.

# %%
sns.distplot(df.Tutoring_Sessions.dropna(), fit=norm)
#распределение не является нормальным
# Out:
# <Axes: xlabel='Tutoring_Sessions', ylabel='Density'>

# %% [markdown]
# График дает представление о рапрседелении данных по дополнительным занятиям с преподавателем. Распределение переменной не является нормальным.

# %%
sns.distplot(df.Sleep_Hours.dropna(), fit=norm)
#не является нормальным
# Out:
# <Axes: xlabel='Sleep_Hours', ylabel='Density'>

# %% [markdown]
# График дает представление о рапрседелении данных по часам сна. Распределение переменной не является нормальным.

# %%
sns.distplot(df.Physical_Activity.dropna(), fit=norm)
#распределение переменной совсем не нормальное
# Out:
# <Axes: xlabel='Physical_Activity', ylabel='Density'>

# %% [markdown]
# График дает представление о рапрседелении данных по количеству часов физической активности. Распределение переменной не является нормальным.

# %% [markdown]
# 3.10. В распределении значений каких метрических переменных наблюдается асимметрия?
#
# Проверим наличие ассиметрии по числовым переменным (перечисленным в 3.9).

# %%
df['Exam_Score'].skew()
# Out:
# 1.6448082853982677

# %% [markdown]
# Значение больше 0, то есть в распределении значений есть положительная ассиметрия.

# %%
df['Previous_Scores'].skew()
# Out:
# -0.00373653379826588

# %% [markdown]
# Значение немного ниже 0, то есть в распределении значений есть незначительная отрицательная ассиметрия.

# %%
df['Attendance'].skew()
# Out:
# 0.013665859547014896

# %% [markdown]
# Значение немного выше 0, то есть в распределении значений есть небольшая положительная ассиметрия.

# %%
df['Hours_Studied'].skew()
# Out:
# 0.013498908859762987

# %% [markdown]
# Значение немного выше 0, то есть в распределении значений есть небольшая положительная ассиметрия.

# %%
df['Tutoring_Sessions'].skew()
# Out:
# 0.8155296028773414

# %% [markdown]
# Значение выше 0, то есть в распределении значений есть положительная ассиметрия.

# %%
df['Physical_Activity'].skew()
# Out:
# -0.031364712236934524

# %% [markdown]
# Значение ниже 0, то есть в распределении значений есть отрицательная ассиметрия.

# %%
df['Sleep_Hours'].skew()
# Out:
# -0.023805436886157025

# %% [markdown]
# Значение ниже 0, то есть в распределении значений есть отрицательная ассиметрия.

# %% [markdown]
# Вывод: положительная ассиметрия наблюдается у переменных Exam_Score, Attendance, Hours_Studied, Tutoring_Sessions. Отрицательная ассиметрия в распределении у переменных Previous_Scores, Physical_Activity, Sleep_Hours.

# %% [markdown]
# Комментарии к заданию и принципам его оценивания:
#
#  - Все пункты задания должны сопровождаться _выполненным_ фрагментом кода.
#  - Если Вы получили результаты в виде статистических показателей, таблиц или графиков, при этом никак их не прокомментировали и не сформулировали содержательные выводы на их основе, то работа оценивается в 0 баллов, в этом случае анализ данных не проведён.
#  - Если Вы полностью выполнили это задание, то получаете за него 8 баллов (отлично). Для получения более высокой оценки нужно выйти за рамки предложенного задания. В случае с текущим заданием это может быть дополнительное самостоятельное изучение инструментов описательного анализа и их применение, или развернутое и глубокое исследование имеющихся данных на основе использования пройденных на занятиях инструментов.
#  - В этом задании три пункта. Первый весит 10%, второй - 40%, третий - 50%.
#  - Задание можно выполнять на русском или на английском языке, критерии оценивания при этом не меняются;
#  - Задание можно выполнять индивидуально или в группе из 2 человек, критерии оценивания при этом не меняются;
#  - В названии загружаемого в Smart LMS файла нужно указать фамилию(ии) автора(ов) работы.

# %% [markdown]
# ### Этот файл нужно сохранить как Jupyter Notebook (.ipynb) и загрузить в Smart LMS до 13:00 31 января. Не рекомендую загружать файл в Smart LMS в последние несколько минут перед дедлайном. После дедлайна выполненные задания не принимаются.
